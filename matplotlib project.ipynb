# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\srava\\Downloads\\dataset.zip")
data
# Out:
#      POS                Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF  \
# 0      1           Virat Kohli   RCB  237   229  34  7263   113  37.25  5586
# 1      2        Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203
# 2      3          David Warner    DC  176   176  22  6397   126  41.54  4572
# 3      4          Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776
# 4      5          Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042
# ..   ...                   ...   ...  ...   ...  ..   ...   ...    ...   ...
# 130  131  Gurkeerat Mann Singh   RCB   39    32   8   511    65  21.29   422
# 131  132         Sai Sudharsan    GT   13    13   2   507    96  46.09   370
# 132  133            Owais Shah    RR   23    22   7   506    76  33.73   389
# 133  134         Paul Valthaty  PBKS   23    23   1   505   120  22.95   418
# 134  135          Sam Billings   KKR   30    27   1   503    56  19.35   388
#
#          SR  100  50   4s   6s
# ...

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     135 non-null    int64
#  1   Player  135 non-null    object
#  2   Team    135 non-null    object
#  3   Mat     135 non-null    int64
#  4   Inns    135 non-null    int64
#  5   NO      135 non-null    int64
#  6   Runs    135 non-null    int64
#  7   HS      135 non-null    object
#  8   Avg     135 non-null    float64
#  9   BF      135 non-null    int64
#  10  SR      135 non-null    float64
#  11  100     135 non-null    int64
#  12  50      135 non-null    int64
#  13  4s      135 non-null    int64
#  14  6s      135 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 15.9+ KB
# None
#               POS         Mat        Inns          NO         Runs  \
# count  135.000000  135.000000  135.000000  135.000000   135.000000
# ...

# %%
data.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042  136.76
#
#    100  50   4s   6s
# 0    7  50  643  234
# 1    2  50  750  148
# 2    4  60  646  226
# 3    1  42  554  257
# 4    1  39  506  203

# %%
data.tail()
# Out:
#      POS                Player  Team  Mat  Inns  NO  Runs   HS    Avg   BF  \
# 130  131  Gurkeerat Mann Singh   RCB   39    32   8   511   65  21.29  422
# 131  132         Sai Sudharsan    GT   13    13   2   507   96  46.09  370
# 132  133            Owais Shah    RR   23    22   7   506   76  33.73  389
# 133  134         Paul Valthaty  PBKS   23    23   1   505  120  22.95  418
# 134  135          Sam Billings   KKR   30    27   1   503   56  19.35  388
#
#          SR  100  50  4s  6s
# 130  121.09    0   2  55  11
# 131  137.03    0   4  47  15
# 132  130.08    0   4  34  23
# 133  120.81    1   2  61  20
# 134  129.64    0   3  40  20

# %%
data.isnull().sum()
# Out:
# POS       0
# Player    0
# Team      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)
data
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 199            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 150402       636       2  Royal Challengers Bangalore
# 150422       636       2  Royal Challengers Bangalore
# 150438       636       2  Royal Challengers Bangalore
# 150448       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball         batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5       DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3        S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2    MC Henriques  Yuvraj Singh
# ...

# %%
data['Player'].values
# Out:
# array(['Virat Kohli', 'Shikhar Dhawan', 'David Warner', 'Rohit Sharma',
#        'Suresh Raina', 'AB de Villiers', 'MS Dhoni', 'Chris Gayle',
#        'Robin Uthappa', 'Dinesh Karthik', 'Ajinkya Rahane',
#        'Ambati Rayudu', 'Gautam Gambhir', 'KL Rahul', 'Faf du Plessis',
#        'Sanju Samson', 'Shane Watson', 'Manish Pandey', 'Kieron Pollard',
#        'Suryakumar Yadav', 'Jos Buttler', 'Yusuf Pathan',
#        'Quinton de Kock', 'Brendon McCullum', 'Parthiv Patel',
#        'Rishabh Pant', 'Wriddhiman Saha', 'Shubman Gill', 'Shreyas Iyer',
#        'Yuvraj Singh', 'Virender Sehwag', 'Glenn Maxwell', 'David Miller',
#        'Ravindra Jadeja', 'Murali Vijay', 'Mayank Agarwal', 'Nitish Rana',
#        'Steve Smith', 'Shaun Marsh', 'Jacques Kallis', 'Dwayne Smith',
#        'Sachin Tendulkar', 'Ishan Kishan', 'Hardik Pandya',
#        'Andre Russell', 'Rahul Dravid', 'Kane Williamson', 'Aaron Finch',
#        'Rahul Tripathi', 'Adam Gilchrist', 'JP Duminy', 'Michael Hussey',
# ...

# %%
data["SR"]=pd.to_numeric(data["SR"])
data["SR"]
# Out:
# 0      130.02
# 1      127.18
# 2      139.92
# 3      130.05
# 4      136.76
#         ...
# 130    121.09
# 131    137.03
# 132    130.08
# 133    120.81
# 134    129.64
# Name: SR, Length: 135, dtype: float64

# %%
display(data[data['Runs']>=5000])
# Out:
#    POS         Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     ViratKohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  ShikharDhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    DavidWarner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    RohitSharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    SureshRaina   CSK  205   200  30  5528  100*  32.52  4042  136.76
# 5    6   ABdeVilliers   RCB  184   170  40  5162  133*  39.70  3403  151.68
# 6    7        MSDhoni   CSK  250   218  87  5082   84*  38.79  3739  135.92
#
#    100  50   4s   6s
# 0    7  50  643  234
# 1    2  50  750  148
# 2    4  60  646  226
# 3    1  42  554  257
# 4    1  39  506  203
# 5    3  40  413  251
# 6    0  24  349  239

# %%
display(data[data.Team=="RCB"])
# Out:
#      POS               Player Team  Mat  Inns  NO  Runs    HS    Avg    BF  \
# 0      1           ViratKohli  RCB  237   229  34  7263   113  37.25  5586
# 5      6         ABdeVilliers  RCB  184   170  40  5162  133*  39.70  3403
# 9     10        DineshKarthik  RCB  242   221  46  4516   97*  25.81  3403
# 14    15         FafduPlessis  RCB  130   123  11  4133    96  36.90  3081
# 23    24      BrendonMcCullum  RCB  109   109   5  2880  158*  27.69  2186
# 24    25         ParthivPatel  RCB  139   137  11  2848    81  22.60  2358
# 31    32         GlennMaxwell  RCB  124   120  17  2719    95  26.40  1725
# 75    76          KedarJadhav  RCB   95    81  27  1208    69  22.37   981
# 102  103       ManvinderBisla  RCB   39    39   1   798    92  21.00   702
# 108  109  TillakaratneDilshan  RCB   38    37   4   735   76*  22.27   666
# 126  127        CoreyAnderson  RCB   30    29   7   538    95  24.45   423
# ...

# %%
display(data[data.Team=="CSK"])
# Out:
#     POS                Player Team  Mat  Inns  NO  Runs    HS    Avg    BF  \
# 4     5           SureshRaina  CSK  205   200  30  5528  100*  32.52  4042
# 6     7               MSDhoni  CSK  250   218  87  5082   84*  38.79  3739
# 8     9          RobinUthappa  CSK  205   197  17  4952    88  27.51  3799
# 10   11         AjinkyaRahane  CSK  172   159  17  4400  105*  30.99  3565
# 11   12          AmbatiRayudu  CSK  204   187  33  4348  100*  28.23  3409
# 16   17           ShaneWatson  CSK  145   141  16  3874  117*  30.99  2809
# 33   34        RavindraJadeja  CSK  226   173  71  2692   62*  26.39  2094
# 34   35           MuraliVijay  CSK  106   106   5  2619   127  25.93  2149
# 51   52         MichaelHussey  CSK   59    58   7  1977   116  38.76  1612
# 53   54        RuturajGaikwad  CSK   52    51   5  1797  101*  39.07  1326
# 58   59           DwayneBravo  CSK  161   113  44  1560   70*  22.61  1204
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('fivethirtyeight')
Team=data[data.RCB=='']

# %%
plt.bar(CSK['Player'],CSK['Team'])
plt.title('Indian Richies')
plt.ylabel('Billion $')
plt.gcf().set_size_inches(10, 5)
plt.xticks(rotation=90)
plt.show()
